# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv("result_2020-03-09.csv")

# %%
df=df.fillna(0)
df
# Out:
#      Unnamed: 0        country  total new case   death  new_death  recovered  \
# 0             1          China  80739       44  3120.0       23.0    58742.0
# 1             2          Italy   9172    1,797   463.0       97.0      724.0
# 2             3       S. Korea   7478      165    53.0        3.0      166.0
# 3             4           Iran   7161      595   237.0       43.0     2394.0
# 4             5         France   1412      203    30.0       11.0       12.0
# ..          ...            ...    ...      ...     ...        ...        ...
# 107         108  Liechtenstein      1        0     0.0        0.0        0.0
# 108         109        Moldova      1        0     0.0        0.0        0.0
# 109         110       Paraguay      1        0     0.0        0.0        0.0
# 110         111      St. Barth      1        0     0.0        0.0        0.0
# 111         112           Togo      1        0     0.0        0.0        0.0
#
#      active_cases  critical
# 0           18877    5111.0
# 1            7985     733.0
# 2            7259      36.0
# 3            4530       0.0
# 4            1370      21.0
# ..            ...       ...
# 107             1       0.0
# 108             1       0.0
# 109             1       0.0
# 110             1       0.0
# 111             1       0.0
#
# [112 rows x 9 columns]

# %%
# f, ax = plt.subplots(figsize=(14, 16))
g=sns.catplot(x="country", y="death",kind="bar", palette="ch:.25", data=df,height=9, aspect=2)
g.set_xticklabels(rotation=90)

# %%
d=df.loc[df['new_death'] > 1]
g=sns.catplot(x="country", y="new_death",kind="bar", palette="ch:.25", data=d,height=8, aspect=2)

# %%
it=pd.read_csv("ita.csv")
it
# Out:
#           date status  hospitalized  Intensive_care  total_hospitalized  \
# 0   2020-02-24    ITA           101              26                 127
# 1   2020-02-25    ITA           114              35                 150
# 2   2020-02-26    ITA           128              36                 164
# 3   2020-02-27    ITA           248              56                 304
# 4   2020-02-28    ITA           345              64                 409
# 5   2020-02-29    ITA           401             105                 506
# 6   2020-03-01    ITA           639             140                 779
# 7   2020-03-02    ITA           742             166                 908
# 8   2020-03-03    ITA          1034             229                1263
# 9   2020-03-04    ITA          1346             295                1641
# 10  2020-03-05    ITA          1790             351                2141
# 11  2020-03-06    ITA          2394             462                2856
# 12  2020-03-07    ITA          2651             567                3218
# 13  2020-03-08    ITA          3557             650                4207
# 14  2020-03-09    ITA          4316             733                5049
#
#     home_isolation  currently_positive  new_currently_positive  \
# 0               94                 221                     221
# 1              162                 311                      90
# 2              221                 385                      74
# 3              284                 588                     203
# 4              412                 821                     233
# 5              543                1049                     228
# 6              798                1577                     528
# 7              927                1835                     258
# 8             1000                2263                     428
# 9             1065                2706                     443
# 10            1155                3296                     590
# 11            1060                3916                     620
# 12            1843                5061                    1145
# 13            2180                6387                    1326
# 14            2936                7985                    1598
#
#     discharged_healed  deceased  total_cases   temponi
# 0                   1         7          229      4324
# 1                   1        10          322      8623
# 2                   3        12          400      9587
# 3                  45        17          650     12014
# 4                  46        21          888     15695
# 5                  50        29         1128     18661
# 6                  83        34         1694     21127
# 7                 149        52         2036     23345
# 8                 160        79         2502     25856
# 9                 276       107         3089     29837
# 10                414       148         3858     32362
# 11                523       197         4636     36359
# 12                589       233         5883     42062
# 13                622       366         7375     49937
# 14                724       463         9172     53826

# %%
plt.figure(figsize=(12, 8))

plt.plot(it['date'].to_numpy(),it['currently_positive'].to_numpy(),label="Current positive")
plt.plot(it['date'].to_numpy(),it['deceased'].to_numpy(),label="Decesed")
plt.plot(it['date'].to_numpy(),it['discharged_healed'].to_numpy(),label="Recovered")
plt.plot(it['date'].to_numpy(),it['total_cases'].to_numpy(),label="Total cases")
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0.)

# %%
# Out:
#    Unnamed: 0 country  total new case  death  new_death  recovered  \
# 1           2   Italy   9172    1,797  463.0       97.0      724.0
#
#    active_cases  critical
# 1          7985     733.0

# %%
list_of_data=['total','new case','death','new_death','recovered','active_cases','critical']
list_of_fields=['hospitalized','home_isolation','currently_positive','discharged_healed','deceased','total_cases','new_currently_positive']

# %%
temp=df.loc[df['country'] == 'Italy']

# %%
rows={}
rows.append('date':)
# Out:
# 1    463.0
# Name: death, dtype: float64
