# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv("result_2020-03-06.csv")

# %%
df=df.fillna(0)
df
# Out:
#     Unnamed: 0           country  total new case   death  new_death  \
# 0            1             China  80576      167  3042.0       30.0
# 1            2          S. Korea   6593      309    43.0        1.0
# 2            3              Iran   4747    1,234   124.0       16.0
# 3            4             Italy   4636      778   197.0       49.0
# 4            5  Diamond Princess    696        0     6.0        0.0
# ..         ...               ...    ...      ...     ...        ...
# 91          92              Peru      1        1     0.0        0.0
# 92          93            Serbia      1        1     0.0        0.0
# 93          94          Slovakia      1        1     0.0        0.0
# 94          95      South Africa      1        0     0.0        0.0
# 95          96              Togo      1        1     0.0        0.0
#
#     active_cases  recovered  critical
# 0          23605    53929.0    5737.0
# 1           6415      135.0      52.0
# 2           3710      913.0       0.0
# 3           3916      523.0     462.0
# 4            478      212.0      34.0
# ..           ...        ...       ...
# 91             1        0.0       0.0
# 92             1        0.0       0.0
# 93             1        0.0       0.0
# 94             1        0.0       0.0
# 95             1        0.0       0.0
#
# [96 rows x 9 columns]

# %%
# f, ax = plt.subplots(figsize=(14, 16))
g=sns.catplot(x="country", y="death",kind="bar", palette="ch:.25", data=df,height=9, aspect=2)
g.set_xticklabels(rotation=90)

# %%
d=df.loc[df['new_death'] > 1]
g=sns.catplot(x="country", y="new_death",kind="bar", palette="ch:.25", data=d,height=8, aspect=2)

# %%
it=pd.read_csv("ita.csv")
it
# Out:
#           date status  hospitalized  home_isolation  currently_positive  \
# 0   2020-02-24    ITA           127              94                 221
# 1   2020-02-25    ITA           147             162                 309
# 2   2020-02-26    ITA           164             221                 385
# 3   2020-02-27    ITA           304             284                 588
# 4   2020-02-28    ITA           409             412                 821
# 5   2020-02-29    ITA           506             543                1049
# 6   2020-03-01    ITA           567             770                1337
# 7   2020-03-02    ITA           908             927                1835
# 8   2020-03-03    ITA          1262            1001                2263
# 9   2020-03-04    ITA          1641            1065                2706
# 10  2020-03-05    ITA          2121            1155                3276
# 11  2020-03-06    ITA          2856            1060                3916
#
#     discharged_healed  deceased  total_cases  new_currently_positive
# 0                   1         7          229                     229
# 1                   1        11          321                      92
# 2                   3        12          400                      79
# 3                  45        17          650                     250
# 4                  45        21          887                     237
# 5                  50        29         1128                     241
# 6                  46        31         1414                     286
# 7                 149        52         2036                     622
# 8                 160        79         2502                     466
# 9                 276       107         3089                     587
# 10                414       148         3838                     749
# 11                523       197         4636                     778

# %%
plt.figure(figsize=(14, 8))

plt.plot(it['date'].to_numpy(),it['currently_positive'].to_numpy(),label="Current positive")
plt.plot(it['date'].to_numpy(),it['deceased'].to_numpy(),label="Decesed")
plt.plot(it['date'].to_numpy(),it['discharged_healed'].to_numpy(),label="Recovered")
plt.plot(it['date'].to_numpy(),it['total_cases'].to_numpy(),label="Total cases")

plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0.)
