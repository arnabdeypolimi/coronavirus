# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pycountry
import geopandas
df=pd.read_csv("daily_data/result_2020-04-01.csv")

# %%
df=df.fillna(0)
df=df.iloc[1:]
df
# Out:
#      Unnamed: 0                 country   total new case    death new_death  \
# 1             2                     USA  205035   16,505   4516.0       463
# 2             3                   Italy  110574    4,782  13155.0       727
# 3             4                   Spain  102136    6,213   9053.0       589
# 4             5                   China   81554       36   3312.0         7
# 5             6                 Germany   76544    4,736    858.0        83
# ..          ...                     ...     ...      ...      ...       ...
# 201         202   Caribbean Netherlands       2        2      0.0         0
# 202         203        Papua New Guinea       1        0      0.0         0
# 203         204  St. Vincent Grenadines       1        0      0.0         0
# 204         205            Sierra Leone       1        0      0.0         0
# 205         206             Timor-Leste       1        0      0.0         0
#
#      recovered  active_cases  critical
# ...

# %%
# f, ax = plt.subplots(figsize=(14, 16))
g=sns.catplot(x="country", y="death",kind="bar", palette="ch:.25", data=df,height=9, aspect=2)
g.set_xticklabels(rotation=90)

# %%
d=df.loc[df['new_death'] > 1]
g=sns.catplot(x="country", y="new_death",kind="bar", palette="ch:.25", data=d,height=8, aspect=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-040c6c817981> in <module>
# ----> 1 d=df.loc[df['new_death'] > 1]
#       2 g=sns.catplot(x="country", y="new_death",kind="bar", palette="ch:.25", data=d,height=8, aspect=2)
#       3
#
# ~\Anaconda3\envs\selenium\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\Anaconda3\envs\selenium\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     524         rvalues = extract_array(other, extract_numpy=True)
#     525
# --> 526         res_values = comparison_op(lvalues, rvalues, op)
#     527
#     528         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# ...

# %%
it=pd.read_csv("ita.csv")
it

# %%
plt.figure(figsize=(12, 8))

plt.plot(it['date'].to_numpy(),it['currently_positive'].to_numpy(),label="Current positive")
plt.plot(it['date'].to_numpy(),it['deceased'].to_numpy(),label="Decesed")
plt.plot(it['date'].to_numpy(),it['discharged_healed'].to_numpy(),label="Recovered")
plt.plot(it['date'].to_numpy(),it['total_cases'].to_numpy(),label="Total cases")
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0.)

# %%
list_of_data=['total','new case','death','new_death','recovered','active_cases','critical']
list_of_fields=['hospitalized','home_isolation','currently_positive','discharged_healed','deceased','total_cases','new_currently_positive']

# %%
temp=df.loc[df['country'] == 'Italy']

# %%
rows={}
rows.append('date':)

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
cities = geopandas.read_file(geopandas.datasets.get_path('naturalearth_cities'))

# %%
world.head(5)
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
fig=plt.figure(figsize=(16, 14))
ax=fig.subplots(1, 1)
world.plot(ax=ax)

# %%
world = world[(world.pop_est>0) & (world.name!="Antarctica")]

world['gdp_per_cap'] = world.gdp_md_est / world.pop_est
fig=plt.figure(figsize=(16, 14))
ax=fig.subplots(1, 1)
world.plot(column='gdp_per_cap',ax=ax);
# Out:
# C:\Users\ARNAB\Anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import pycountry

c=pycountry.countries.search_fuzzy('korea')
c
# Out:
# [Country(alpha_2='KP', alpha_3='PRK', name="Korea, Democratic People's Republic of", numeric='408', official_name="Democratic People's Republic of Korea"),
#  Country(alpha_2='KR', alpha_3='KOR', name='Korea, Republic of', numeric='410')]

# %%
ls=[]
for i in list(pycountry.countries):
    ls.append(i.name)

# %%
ls
# Out:
# ['Aruba',
#  'Afghanistan',
#  'Angola',
#  'Anguilla',
#  'Åland Islands',
#  'Albania',
#  'Andorra',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'American Samoa',
#  'Antarctica',
#  'French Southern Territories',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Bonaire, Sint Eustatius and Saba',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas',
#  'Bosnia and Herzegovina',
#  'Saint Barthélemy',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia, Plurinational State of',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Bhutan',
#  'Bouvet Island',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Cocos (Keeling) Islands',
#  'Switzerland',
#  'Chile',
#  'China',
#  "Côte d'Ivoire",
#  'Cameroon',
#  'Congo, The Democratic Republic of the',
#  'Congo',
#  'Cook Islands',
#  'Colombia',
#  'Comoros',
#  'Cabo Verde',
#  'Costa Rica',
#  'Cuba',
# ...

# %%
countries=d.country.values
input_countries = countries

countries = {}
for country in pycountry.countries:
    countries[country.name] = country.alpha_3

codes = [countries.get(country, 'Unknown code') for country in input_countries]

print(codes)  # prints ['AS', 'CA', 'FR']
# Out:
# ['Unknown code', 'ITA', 'ESP', 'CHN', 'DEU', 'FRA', 'Unknown code', 'Unknown code', 'CHE', 'TUR', 'BEL', 'NLD', 'AUT', 'Unknown code', 'CAN', 'PRT', 'BRA', 'ISR', 'SWE', 'AUS', 'NOR', 'CZE', 'IRL', 'DNK', 'CHL', 'MYS', 'Unknown code', 'ECU', 'ROU', 'POL', 'LUX', 'PHL', 'JPN', 'PAK', 'THA', 'SAU', 'IDN', 'IND', 'FIN', 'GRC', 'ZAF', 'DOM', 'ISL', 'MEX', 'PAN', 'PER', 'SRB', 'ARG', 'SGP', 'HRV', 'COL', 'DZA', 'SVN', 'QAT', 'EST', 'HKG', 'Unknown code', 'EGY', 'NZL', 'IRQ', 'UKR', 'Unknown code', 'MAR', 'LTU', 'ARM', 'BHR', 'HUN', 'LBN', 'BIH', 'LVA', 'TUN', 'Unknown code', 'BGR', 'SVK', 'AND', 'KAZ', 'AZE', 'MKD', 'CRI', 'URY', 'Unknown code', 'CYP', 'KWT', 'REU', 'JOR', 'BFA', 'ALB', 'SMR', 'CMR', 'Unknown code', 'CUB', 'OMN', 'AFG', 'GHA', 'SEN', 'MLT', 'Unknown code', 'UZB', 'Unknown code', 'HND']
