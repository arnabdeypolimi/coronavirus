# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv("result_2020-03-05.csv")

# %%
df=df.fillna(0)
df
# Out:
#     Unnamed: 0           country  total  new case   death  new_death  \
# 0            1             China  80430     160.0  3013.0       32.0
# 1            2          S. Korea   6088     467.0    40.0        5.0
# 2            3             Italy   3858     769.0   148.0       41.0
# 3            4              Iran   3513     591.0   107.0       15.0
# 4            5  Diamond Princess    696       0.0     6.0        0.0
# ..         ...               ...    ...       ...     ...        ...
# 82          83           Ukraine      1       0.0     0.0        0.0
# 83          84         Argentina      1       0.0     0.0        0.0
# 84          85     Liechtenstein      1       0.0     0.0        0.0
# 85          86            Poland      1       0.0     0.0        0.0
# 86          87      South Africa      1       1.0     0.0        0.0
#
#     active_cases  recovered  critical
# 0          25158    52259.0    5952.0
# 1           5913      135.0      52.0
# 2           3296      414.0     351.0
# 3           2667      739.0       0.0
# 4            478      212.0      35.0
# ..           ...        ...       ...
# 82             1        0.0       0.0
# 83             1        0.0       0.0
# 84             1        0.0       0.0
# 85             1        0.0       0.0
# 86             1        0.0       0.0
#
# [87 rows x 9 columns]

# %%
# f, ax = plt.subplots(figsize=(14, 16))
g=sns.catplot(x="country", y="death",kind="bar", palette="ch:.25", data=df,height=9, aspect=2)
g.set_xticklabels(rotation=90)

# %%
d=df.loc[df['new_death'] > 1]
g=sns.catplot(x="country", y="new_death",kind="bar", palette="ch:.25", data=d,height=8, aspect=2)
g.set_xticklabels(rotation=90)
